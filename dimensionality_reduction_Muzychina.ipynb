# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, TruncatedSVD, NMF


data = pd.read_csv('drive/MyDrive/Colab Notebooks/BankChurners_ML.csv')
x = data[data.columns[1:20]]
x
# Out:
#               2    3    4    5  ...        17        18        19        20
# 0      0.404255  1.0  0.6  0.6  ...  0.035273  0.248062  0.875067  0.061061
# 1      0.382979  1.0  0.4  0.4  ...  0.032158  0.108527  0.455574  0.311311
# 2      0.468085  1.0  0.4  0.4  ...  0.051797  0.170543  0.474960  0.144144
# 3      0.340426  1.0  1.0  1.0  ...  0.038444  0.248062  0.366182  0.217217
# 4      0.829787  1.0  0.2  0.4  ...  0.044731  0.124031  0.734518  0.174174
# ...         ...  ...  ...  ...  ...       ...       ...       ...       ...
# 10057  0.510638  1.0  0.4  0.4  ...  0.832647  0.829457  0.461497  0.462462
# 10058  0.319149  1.0  0.4  0.4  ...  0.459219  0.457364  0.367798  0.511512
# 10059  0.382979  0.0  0.2  0.6  ...  0.544175  0.387597  0.440495  0.000000
# 10060  0.085106  1.0  0.4  0.4  ...  0.438689  0.403101  0.388799  0.000000
# 10061  0.361702  0.0  0.4  0.4  ...  0.544342  0.395349  0.349488  0.189189
#
# [10062 rows x 19 columns]

# %% [markdown]
# # Using 3 matrix factorization methods, project features on a subspace

# %%
proj1 = {}
proj1[2] = PCA(2).fit(x).transform(x)
proj1[3] = PCA(3).fit(x).transform(x)


proj2 = {}
proj2[2] = TruncatedSVD(2).fit(x).transform(x)
proj2[3] = TruncatedSVD(3).fit(x).transform(x)


proj3 = {}
proj3[2] = NMF(2).fit(x).transform(x)
proj3[3] = NMF(3).fit(x).transform(x)

# %% [markdown]
# # Using 3 methods, visualize feature space in 2D and 3D. Try to spot inner structure.

# %%
fig = plt.figure(figsize=(30, 12))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122, projection='3d')

ax1.scatter(x=proj1[2][:, 0], y=proj1[2][:, 1])
ax2.scatter(xs=proj1[3][:, 0], ys=proj1[3][:, 1], zs=proj1[3][:, 2])


fig = plt.figure(figsize=(30, 12))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122, projection='3d')

ax1.scatter(x=proj2[2][:, 0], y=proj2[2][:, 1])
ax2.scatter(xs=proj2[3][:, 0], ys=proj2[3][:, 1], zs=proj2[3][:, 2])


fig = plt.figure(figsize=(30, 12))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122, projection='3d')

ax1.scatter(x=proj3[2][:, 0], y=proj3[2][:, 1])
ax2.scatter(xs=proj3[3][:, 0], ys=proj3[3][:, 1], zs=proj3[3][:, 2])

plt.show()
